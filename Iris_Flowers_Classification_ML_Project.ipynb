# %% [markdown]
# <a href="https://colab.research.google.com/github/nivethitha2001/LGMVIP-DataScience-Intern/blob/main/Iris_Flowers_Classification_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK-2**
# ## **IRIS FLOWERS CLASSIFICATION ML PROJECT**
# DONE BY: NIVETHITHA.S

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# **IMPORTING THE DATASET**

# %%
iris_data=pd.read_csv("iris.csv")

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **CHECKING THE NULL DATA PRESENT IN THE DATASET**

# %%
iris_data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **PAIR PLOT**

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue='species', size=3, palette='Set1')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
Species = pd.get_dummies(iris['species'])

# %%
iris.pop('species')
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
iris= pd.concat([iris_data,Species],axis = 1)
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  ...  setosa  versicolor virginica
# 0      1            5.1           3.5  ...       1           0         0
# 1      2            4.9           3.0  ...       1           0         0
# 2      3            4.7           3.2  ...       1           0         0
# 3      4            4.6           3.1  ...       1           0         0
# 4      5            5.0           3.6  ...       1           0         0
# ..   ...            ...           ...  ...     ...         ...       ...
# 145  146            6.7           3.0  ...       0           0         1
# 146  147            6.3           2.5  ...       0           0         1
# 147  148            6.5           3.0  ...       0           0         1
# 148  149            6.2           3.4  ...       0           0         1
# 149  150            5.9           3.0  ...       0           0         1
#
# [150 rows x 9 columns]

# %%
iris_data.pop('Id')
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %% [markdown]
# **PREPROCESSING**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
iris_data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
X = iris_data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = Species

# %%
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(X)

# %%
df_feat = pd.DataFrame(scaled_features,columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])
df_feat
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0        -0.900681      1.032057      -1.341272     -1.312977
# 1        -1.143017     -0.124958      -1.341272     -1.312977
# 2        -1.385353      0.337848      -1.398138     -1.312977
# 3        -1.506521      0.106445      -1.284407     -1.312977
# 4        -1.021849      1.263460      -1.341272     -1.312977
# ..             ...           ...            ...           ...
# 145       1.038005     -0.124958       0.819624      1.447956
# 146       0.553333     -1.281972       0.705893      0.922064
# 147       0.795669     -0.124958       0.819624      1.053537
# 148       0.432165      0.800654       0.933356      1.447956
# 149       0.068662     -0.124958       0.762759      0.790591
#
# [150 rows x 4 columns]

# %%
df_feat = pd.concat([df_feat,Species],axis = 1)
df_feat
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  ...  setosa  versicolor  virginica
# 0        -0.900681      1.032057      -1.341272  ...       1           0          0
# 1        -1.143017     -0.124958      -1.341272  ...       1           0          0
# 2        -1.385353      0.337848      -1.398138  ...       1           0          0
# 3        -1.506521      0.106445      -1.284407  ...       1           0          0
# 4        -1.021849      1.263460      -1.341272  ...       1           0          0
# ..             ...           ...            ...  ...     ...         ...        ...
# 145       1.038005     -0.124958       0.819624  ...       0           0          1
# 146       0.553333     -1.281972       0.705893  ...       0           0          1
# 147       0.795669     -0.124958       0.819624  ...       0           0          1
# 148       0.432165      0.800654       0.933356  ...       0           0          1
# ...

# %% [markdown]
# **GENERATING THE MODEL**
#
# **TRAIN_TEST_SPLIT**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_feat,Species,test_size = 0.3, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(7)

# %% [markdown]
# **MODEL FITTING**

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %% [markdown]
# **CLASSIFICATION REPORT**

# %%
from sklearn.metrics import classification_report

# %%
predictions = knn.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#    micro avg       1.00      1.00      1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#  samples avg       1.00      1.00      1.00        45
