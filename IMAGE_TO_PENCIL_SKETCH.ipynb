# %% [markdown]
# <a href="https://colab.research.google.com/github/nivethitha2001/LGMVIP-DataScience-Intern/blob/main/IMAGE_TO_PENCIL_SKETCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK -1**
#
# # **IMAGE TO PENCIL SKETCH WITH PYTHON**
#
# DONE BY: NIVETHITHA

# %% [markdown]
# **IMPORTING**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('DOLL.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=333x500 at 0x7F61E6384750>
# -1

# %% [markdown]
# **GRAY-SCALE IMAGE**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=333x500 at 0x7F61F3943650>
# -1

# %% [markdown]
# **NEGATIVE IMAGE**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=333x500 at 0x7F61E6375750>
# -1

# %% [markdown]
# **BLURRED IMAGE**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=333x500 at 0x7F61E63750D0>
# -1

# %% [markdown]
# **PENCIL SKETCH IMAGE**

# %%
print("OUTPUT :")
print("\n PENCIL SKETCH \n")
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# OUTPUT :
#
#  PENCIL SKETCH
# <PIL.Image.Image image mode=L size=333x500 at 0x7F61E63A3710>
# -1
